# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
df = pd.read_csv("Word_cloud.csv",header=None)

# %%
pd.read_csv?

# %%
df
# Out:
#                           0                                                 1
# 0   Imperial College London   Mathematics for Machine Learning Specialization
# 1                       IBM               Applied Data Science Specialization
# 2                       IBM                   IBM Data Science Specialization
# 3                       IBM                    to Data Science Specialization
# 4                  UC Davis  Data Wrangling, Analysis and AB Testing with SQL
# ..                      ...                                               ...
# 67                      NaN                                          Stanford
# 68                      NaN                                          Harvardx
# 69                      NaN                                           UCDavis
# 70                      NaN                             ImperialCollegeLondon
# 71                      NaN                                              MITx
#
# [72 rows x 2 columns]

# %%
comment_words = '' 
stopwords = set(STOPWORDS) 
t=('introduction','getting','started','essential','training','ab','bc')
stopwords.update(t)
print(stopwords)
# Out:
# {'only', 'few', 'can', 'up', 'was', "here's", 'any', "let's", 'down', 'below', 'more', 'itself', 'other', 'otherwise', "you're", 'as', 'their', 'such', 'against', "wouldn't", "don't", "didn't", "i've", 'but', 'once', 'have', 'my', 'introduction', 'is', 'then', 'in', 'no', 'they', 'himself', 'also', 'ab', 'there', "won't", "they've", 'between', 'i', 'over', 'been', 'so', 'get', "you'd", 'and', 'training', "wasn't", 'k', "isn't", "that's", 'these', 'if', "we're", 'doing', 'just', 'until', "i'll", "they'd", 'are', 'when', "haven't", "when's", 'all', 'had', 'did', 'bc', 'shall', 'again', 'http', 'during', 'how', 'our', 'him', "they'll", 'most', 'what', 'since', "hasn't", 'at', "she'd", 'those', 'an', 'myself', 'here', 'further', "he'll", 'com', 'that', 'some', "it's", 'cannot', 'ourselves', 'getting', 'through', "they're", 'than', 'could', 'ought', 'www', "couldn't", "we've", "doesn't", 'she', 'a', "can't", 'after', 'with', "why's", 'your', 'nor', "weren't", 'you', 'does', 'which', 'out', 'ever', 'do', 'themselves', "i'm", "you've", 'or', "how's", "i'd", 'from', 'we', 'them', 'on', 'should', "we'll", "aren't", 'each', 'by', "what's", 'would', 'however', 'be', 'started', 'to', "who's", 'why', 'where', 'theirs', 'same', 'am', "she's", 'r', 'not', "shan't", 'her', 'about', 'under', 'has', "we'd", 'above', 'yourself', 'too', 'who', 'for', 'off', 'therefore', 'own', 'were', "mustn't", 'ours', "you'll", 'this', 'yours', 'yourselves', 'whom', "shouldn't", "hadn't", 'hence', 'it', 'like', 'me', 'he', "she'll", 'hers', 'its', "where's", 'his', "he'd", 'being', 'herself', 'both', 'into', 'else', 'of', "there's", 'essential', 'before', 'while', 'because', 'very', 'the', 'having', "he's"}

# %%
  
# iterate through the csv file 
for val in df[1]: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
      
    comment_words += " ".join(tokens)+" "
  
wordcloud = WordCloud(width = 1000, height = 250, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.savefig("wordcloud.png", dpi=2000)
plt.show()
